# %%
import pandas as pd
google_play_apps = pd.read_csv('C:/Users/Administrator/dataset/googleplaystore.csv')
google_play_apps.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#Question 1

print('Jumlah baris adalah ' + str(google_play_apps.shape[0]) + ' dan jumlah kolom adalah '+str(google_play_apps.shape[1]))
# Out:
# Jumlah baris adalah 10841 dan jumlah kolom adalah 13

# %%
google_play_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Create DataFrame 
df = pd.DataFrame(google_play_apps) 
# Print the output. 
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
df.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
# Question 2

df['Category'].nunique()
# Out:
# 34

# %%
# Question 3

df['Genres'].nunique()
# Out:
# 120

# %%
# Question 4

google_play_apps.drop_duplicates(subset='App', inplace=True)

# %%
# Question 5

google_play_apps[google_play_apps['Installs']=='Free']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
google_play_apps = google_play_apps[google_play_apps['Installs'] != 'Free']

# %%
google_play_apps['Installs'] = google_play_apps ['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
google_play_apps['Installs'] = google_play_apps ['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
google_play_apps['Reviews'] = google_play_apps ['Reviews'].apply(lambda x: x.replace('M', '') if 'M' in str(x) else x)

# %%
# Question 6

google_play_apps['Installs'] = google_play_apps ['Installs'].astype(int)

# %%
# Question 7

google_play_apps[google_play_apps['App']=='WhatsApp Messenger']
# Out:
#                     App       Category  Rating   Reviews                Size  \
# 336  WhatsApp Messenger  COMMUNICATION     4.4  69119316  Varies with device
#
#        Installs  Type Price Content Rating         Genres    Last Updated  \
# 336  1000000000  Free     0       Everyone  Communication  August 3, 2018
#
#             Current Ver         Android Ver
# 336  Varies with device  Varies with device

# %%
google_play_apps[google_play_apps['App']=='Dropbox']
# Out:
#           App      Category  Rating  Reviews Size   Installs  Type Price  \
# 3473  Dropbox  PRODUCTIVITY     4.4  1861310  61M  500000000  Free     0
#
#      Content Rating        Genres    Last Updated         Current Ver  \
# 3473       Everyone  Productivity  August 1, 2018  Varies with device
#
#              Android Ver
# 3473  Varies with device

# %%
google_play_apps[google_play_apps['App']=='DU Battery Saver - Battery Charger & Battery Life']
# Out:
#                                                     App Category  Rating  \
# 8896  DU Battery Saver - Battery Charger & Battery Life    TOOLS     4.5
#
#        Reviews Size   Installs  Type Price Content Rating Genres  \
# 8896  13479633  14M  100000000  Free     0       Everyone  Tools
#
#       Last Updated Current Ver Android Ver
# 8896  June 5, 2018     4.8.7.8  4.0 and up

# %%
google_play_apps[google_play_apps['App']=='Pinterest']
# Out:
#             App Category  Rating  Reviews                Size   Installs  \
# 2552  Pinterest   SOCIAL     4.6  4305441  Varies with device  100000000
#
#       Type Price Content Rating  Genres    Last Updated         Current Ver  \
# 2552  Free     0           Teen  Social  August 3, 2018  Varies with device
#
#              Android Ver
# 2552  Varies with device

# %%
google_play_apps[google_play_apps['App']=='Subway Surfers']
# Out:
#                  App Category  Rating   Reviews Size    Installs  Type Price  \
# 1654  Subway Surfers     GAME     4.5  27722264  76M  1000000000  Free     0
#
#      Content Rating  Genres   Last Updated Current Ver Android Ver
# 1654   Everyone 10+  Arcade  July 12, 2018      1.90.0  4.1 and up

# %%
google_play_apps[google_play_apps['App']=='File Commander - File Manager/Explorer']
# Out:
#                                           App  Category  Rating Reviews Size  \
# 10253  File Commander - File Manager/Explorer  BUSINESS     4.3  758590  12M
#
#         Installs  Type Price Content Rating    Genres    Last Updated  \
# 10253  100000000  Free     0       Everyone  Business  August 2, 2018
#
#               Current Ver Android Ver
# 10253  Varies with device  4.1 and up

# %%
google_play_apps[google_play_apps['App']=='Flipboard: News For Our Time']
# Out:
#                                App            Category  Rating  Reviews  \
# 3755  Flipboard: News For Our Time  NEWS_AND_MAGAZINES     4.4  1284017
#
#                     Size   Installs  Type Price Content Rating  \
# 3755  Varies with device  500000000  Free     0   Everyone 10+
#
#                 Genres    Last Updated         Current Ver         Android Ver
# 3755  News & Magazines  August 3, 2018  Varies with device  Varies with device

# %%
google_play_apps[google_play_apps['App']=='FIFA Soccer']
# Out:
#               App Category  Rating  Reviews Size   Installs  Type Price  \
# 8445  FIFA Soccer   SPORTS     4.2  3909032  51M  100000000  Free     0
#
#      Content Rating  Genres   Last Updated Current Ver Android Ver
# 8445       Everyone  Sports  July 31, 2018     10.5.00  4.1 and up

# %%
# Question 8

google_play_apps[google_play_apps['Installs'] >=1000000000]
# Out:
#                                            App             Category  Rating  \
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                         WhatsApp Messenger        COMMUNICATION     4.4
# 338               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                      Gmail        COMMUNICATION     4.3
# 341                                   Hangouts        COMMUNICATION     4.0
# 391              Skype - free IM & video calls        COMMUNICATION     4.1
# 865                          Google Play Games        ENTERTAINMENT     4.3
# 1654                            Subway Surfers                 GAME     4.5
# 2544                                  Facebook               SOCIAL     4.1
# 2545                                 Instagram               SOCIAL     4.5
# ...

# %%
# Question 9

app_comunication = google_play_apps[google_play_apps['Category'] == 'COMMUNICATION']
app_comunication.sort_values(by=['Reviews'], ascending=False).head(10)
# Out:
#                                       App       Category  Rating  Reviews  \
# 353                     MegaFon Dashboard  COMMUNICATION     3.7    99559
# 10739      FreedomPop Messaging Phone/SIM  COMMUNICATION     3.6     9894
# 9922                             Inbox.eu  COMMUNICATION     3.7       98
# 10456                              Sat-Fi  COMMUNICATION     3.6       97
# 6774                         BT Messenger  COMMUNICATION     3.9       97
# 338          Google Chrome: Fast & Secure  COMMUNICATION     4.3  9642995
# 4389                         N-Com Wizard  COMMUNICATION     3.3      960
# 450                           Caller ID +  COMMUNICATION     4.0     9498
# 8021               Koch Morse Trainer Pro  COMMUNICATION     4.6       94
# 8904   Caller ID & Call Block - DU Caller  COMMUNICATION     4.6    93930
#
#                      Size    Installs  Type  Price Content Rating  \
# 353    Varies with device    10000000  Free      0       Everyone
# ...

# %%
# Question 10

google_play_apps.drop_duplicates(subset='App', inplace=True)
google_play_apps['Rating'] = google_play_apps ['Rating'].astype(float)

game_category = google_play_apps[google_play_apps['Category'] == 'GAME']
game_category[['App','Installs','Reviews']].sort_values(by=['Installs', 'Reviews'], ascending=False).head(3)
# Out:
#                    App    Installs   Reviews
# 1654    Subway Surfers  1000000000  27722264
# 1661      Temple Run 2   500000000   8118609
# 1655  Candy Crush Saga   500000000  22426677
